# %% [raw]
# Data is Crazy, if it is stock data. I have not manipulated the data

# %% [raw]
# I tried muultiple things like tradingview lightweight charts, the library is avialable for js and python. used plotly but doesnt look good.

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#       Timestamp   Open   High    Low  Close  Volume
# 0      1/3/2010  79.63  80.00  79.63  79.94    1504
# 1      1/4/2010  79.95  81.79  79.77  81.64  235993
# 2      1/5/2010  81.63  82.00  80.95  81.63  242964
# 3      1/6/2010  81.63  83.52  80.85  83.14  351197
# 4      1/7/2010  83.13  83.36  82.26  82.60  221837
# ...         ...    ...    ...    ...    ...     ...
# 3565  6/20/2021  71.52  71.92  71.48  71.89     988
# 3566  6/21/2021  71.89  73.96  71.15  73.42   83896
# 3567  6/22/2021  73.39  73.95  72.87  72.95   18838
# 3568  6/23/2021  72.95  74.25  72.82  73.23  407704
# 3569  6/24/2021  73.22  73.27  73.16  73.17     905
#
# [3570 rows x 6 columns]

# %%
value = []
for i in df.columns[1:]:
    value.append(min(df[i]))
value
# Out:
# [-11.12, 13.69, -40.32, -11.1, 24]

# %%
import pandas as pd
import mplfinance as mpf
import ta  # Technical Analysis Library


def calculate_atr(df, period=14):
    """Calculate ATR using the True Range formula."""
    df['ATR'] = ta.volatility.average_true_range(df['high'], df['low'], df['close'], window=period)
    return df


if __name__ == '__main__':
    # ✅ Load CSV Data
    df = pd.read_csv('data.csv')

    # ✅ Convert Timestamp to Datetime Format
    df['time'] = pd.to_datetime(df['Timestamp'])
    df.set_index('time', inplace=True)  # Required for mplfinance

    # ✅ Rename columns for mplfinance
    df.rename(columns={'Open': 'open', 'High': 'high', 'Low': 'low', 'Close': 'close', 'Volume': 'volume'}, inplace=True)

    # ✅ Calculate ATR
    df = calculate_atr(df, period=14)

    # ✅ Define Subplots
    apds = [mpf.make_addplot(df['ATR'], panel=1, color='red', ylabel='ATR')]

    # ✅ Plot Candlestick Chart with ATR Below
    mpf.plot(df, type='candle', volume=True, addplot=apds, style='charles', figsize=(12, 6))
# Out:
# C:\Users\Rushi\AppData\Local\Programs\Python\Python311\Lib\site-packages\mplfinance\_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+
